# %% [markdown]
# **Renata Daou**

# %%
from dotenv import load_dotenv
load_dotenv()
import os

# %%
API_KEY = os.getenv('API_KEY')

# %%
import requests

# %%
documents = "https://www.weatherapi.com/docs/"
print("Documentation URL:", documents)
# Out:
# Documentation URL: https://www.weatherapi.com/docs/

# %%
import requests

documents = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q=Manaus&aqi=no"
print("Documentation URL:", documents)
# Out:
# Documentation URL: http://api.weatherapi.com/v1/current.json?key=07ba3901e800461ba55223411231211&q=Manaus&aqi=no

# %%
import requests

url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q=Manaus&aqi=no"
response = requests.get(url)
data = response.json()
print(data)
print(data.keys())
# Out:
# {'location': {'name': 'Manaus', 'region': 'Amazonas', 'country': 'Brazil', 'lat': -3.11, 'lon': -60.03, 'tz_id': 'America/Manaus', 'localtime_epoch': 1700021949, 'localtime': '2023-11-15 0:19'}, 'current': {'last_updated_epoch': 1700021700, 'last_updated': '2023-11-15 00:15', 'temp_c': 30.0, 'temp_f': 86.0, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 3.8, 'wind_kph': 6.1, 'wind_degree': 30, 'wind_dir': 'NNE', 'pressure_mb': 1007.0, 'pressure_in': 29.74, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 59, 'cloud': 0, 'feelslike_c': 31.1, 'feelslike_f': 87.9, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 8.9, 'gust_kph': 14.4}}
# dict_keys(['location', 'current'])

# %%
url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q=Manaus&aqi=no"
response = requests.get(url)
data = response.json()
print(data['location']['country'])
# Out:
# Brazil

# %%
data
# Out:
# {'location': {'name': 'Manaus',
#   'region': 'Amazonas',
#   'country': 'Brazil',
#   'lat': -3.11,
#   'lon': -60.03,
#   'tz_id': 'America/Manaus',
#   'localtime_epoch': 1700012469,
#   'localtime': '2023-11-14 21:41'},
#  'current': {'last_updated_epoch': 1700011800,
#   'last_updated': '2023-11-14 21:30',
#   'temp_c': 32.0,
#   'temp_f': 89.6,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 3.8,
#   'wind_kph': 6.1,
#   'wind_degree': 30,
#   'wind_dir': 'NNE',
#   'pressure_mb': 1007.0,
#   'pressure_in': 29.74,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 52,
#   'cloud': 0,
#   'feelslike_c': 33.8,
#   'feelslike_f': 92.8,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 1.0,
#   'gust_mph': 5.6,
#   'gust_kph': 9.1}}

# %%
data.keys()
# Out:
# dict_keys(['location', 'current'])

# %%
data['current']
# Out:
# {'last_updated_epoch': 1700011800,
#  'last_updated': '2023-11-14 21:30',
#  'temp_c': 32.0,
#  'temp_f': 89.6,
#  'is_day': 0,
#  'condition': {'text': 'Clear',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#   'code': 1000},
#  'wind_mph': 3.8,
#  'wind_kph': 6.1,
#  'wind_degree': 30,
#  'wind_dir': 'NNE',
#  'pressure_mb': 1007.0,
#  'pressure_in': 29.74,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 52,
#  'cloud': 0,
#  'feelslike_c': 33.8,
#  'feelslike_f': 92.8,
#  'vis_km': 10.0,
#  'vis_miles': 6.0,
#  'uv': 1.0,
#  'gust_mph': 5.6,
#  'gust_kph': 9.1}

# %%
data['current']['temp_f']
# Out:
# 89.6

# %%
data['current']['feelslike_f']- data['current']['temp_f']
# Out:
# 3.200000000000003

# %%
import requests

url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q=London&aqi=yes"
response = requests.get(url)
data = response.json()
print(data)
print(data.keys())
# Out:
# {'location': {'name': 'London', 'region': 'City of London, Greater London', 'country': 'United Kingdom', 'lat': 51.52, 'lon': -0.11, 'tz_id': 'Europe/London', 'localtime_epoch': 1700019072, 'localtime': '2023-11-15 3:31'}, 'current': {'last_updated_epoch': 1700018100, 'last_updated': '2023-11-15 03:15', 'temp_c': 9.0, 'temp_f': 48.2, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 10.5, 'wind_kph': 16.9, 'wind_degree': 250, 'wind_dir': 'WSW', 'pressure_mb': 1013.0, 'pressure_in': 29.91, 'precip_mm': 0.01, 'precip_in': 0.0, 'humidity': 93, 'cloud': 0, 'feelslike_c': 6.3, 'feelslike_f': 43.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 17.3, 'gust_kph': 27.9, 'air_quality': {'co': 237.0, 'no2': 8.1, 'o3': 57.9, 'so2': 3.6, 'pm2_5': 1.2, 'pm10': 2.5, 'us-epa-index': 1, 'gb-defra-index': 1}}}
# dict_keys(['location', 'current'])

# %%
data.keys()
# Out:
# dict_keys(['location', 'current'])

# %%
data['current']['temp_c']
# Out:
# 9.0

# %%
import requests

documents = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=lhr&days=3&aqi=yes&alerts=yes"
print("Documentation URL:", documents)
# Out:
# Documentation URL: http://api.weatherapi.com/v1/forecast.json?key=07ba3901e800461ba55223411231211&q=lhr&days=3&aqi=yes&alerts=yes

# %%
import requests

url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=lhr&days=3&aqi=yes&alerts=yes"
response = requests.get(url)
data = response.json()
print(data)
print(data.keys())
# Out:
# {'location': {'name': 'London Heathrow Airport', 'region': 'London', 'country': 'United Kingdom', 'lat': 51.47, 'lon': -0.46, 'tz_id': 'Europe/London', 'localtime_epoch': 1700019125, 'localtime': '2023-11-15 3:32'}, 'current': {'last_updated_epoch': 1700018100, 'last_updated': '2023-11-15 03:15', 'temp_c': 9.0, 'temp_f': 48.2, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 8.1, 'wind_kph': 13.0, 'wind_degree': 260, 'wind_dir': 'W', 'pressure_mb': 1013.0, 'pressure_in': 29.91, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 93, 'cloud': 0, 'feelslike_c': 6.3, 'feelslike_f': 43.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 17.9, 'gust_kph': 28.8, 'air_quality': {'co': 233.7, 'no2': 5.6, 'o3': 60.8, 'so2': 1.9, 'pm2_5': 1.1, 'pm10': 2.4, 'us-epa-index': 1, 'gb-defra-index': 1}}, 'forecast': {'forecastday': [{'date': '2023-11-15', 'date_epoch': 1700006400, 'day': {'maxtemp_c': 10.8, 'maxtemp
# ...

# %%
data.keys()
# Out:
# dict_keys(['location', 'current', 'forecast', 'alerts'])

# %%
data['forecast']
# Out:
# {'forecastday': [{'date': '2023-11-15',
#    'date_epoch': 1700006400,
#    'day': {'maxtemp_c': 10.8,
#     'maxtemp_f': 51.5,
#     'mintemp_c': 7.1,
#     'mintemp_f': 44.9,
#     'avgtemp_c': 9.3,
#     'avgtemp_f': 48.7,
#     'maxwind_mph': 14.5,
#     'maxwind_kph': 23.4,
#     'totalprecip_mm': 0.21,
#     'totalprecip_in': 0.01,
#     'totalsnow_cm': 0.0,
#     'avgvis_km': 10.0,
#     'avgvis_miles': 6.0,
#     'avghumidity': 77.0,
#     'daily_will_it_rain': 1,
#     'daily_chance_of_rain': 87,
#     'daily_will_it_snow': 0,
#     'daily_chance_of_snow': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#      'code': 1063},
#     'uv': 2.0,
#     'air_quality': {'co': 238.06799999999998,
#      'no2': 14.255999999999998,
#      'o3': 57.96799999999999,
#      'so2': 3.1240000000000006,
#      'pm2_5': 1.4399999999999997,
#      'pm10': 2.7880000000000003,
#      'us-epa-index': 1,
# ...

# %%
data['forecast']['forecastday']
# Out:
# [{'date': '2023-11-15',
#   'date_epoch': 1700006400,
#   'day': {'maxtemp_c': 10.8,
#    'maxtemp_f': 51.5,
#    'mintemp_c': 7.1,
#    'mintemp_f': 44.9,
#    'avgtemp_c': 9.3,
#    'avgtemp_f': 48.7,
#    'maxwind_mph': 14.5,
#    'maxwind_kph': 23.4,
#    'totalprecip_mm': 0.21,
#    'totalprecip_in': 0.01,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 77.0,
#    'daily_will_it_rain': 1,
#    'daily_chance_of_rain': 87,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#     'code': 1063},
#    'uv': 2.0,
#    'air_quality': {'co': 238.06799999999998,
#     'no2': 14.255999999999998,
#     'o3': 57.96799999999999,
#     'so2': 3.1240000000000006,
#     'pm2_5': 1.4399999999999997,
#     'pm10': 2.7880000000000003,
#     'us-epa-index': 1,
#     'gb-defra-index': 1}},
#   'astro': {'sunrise': '07:19 AM',
# ...

# %%
import requests

url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=lhr&days=3&aqi=yes&alerts=yes"
response = requests.get(url)
data = response.json()

forecast = data['forecast']
for forecastday in forecast["forecastday"]:
    date = forecastday["date"]
    print(forecastday.keys())
# Out:
# dict_keys(['date', 'date_epoch', 'day', 'astro', 'hour'])
# dict_keys(['date', 'date_epoch', 'day', 'astro', 'hour'])
# dict_keys(['date', 'date_epoch', 'day', 'astro', 'hour'])

# %%
url = "http://api.weatherapi.com/v1/forecast.json?key=07ba3901e800461ba55223411231211&q=lhr&days=3&aqi=yes&alerts=yes"
response = requests.get(url)
data = response.json()

forecast = data['forecast']
for forecastday in forecast["forecastday"]:
    date = forecastday["date"]
    print(forecastday['day'])
# Out:
# {'maxtemp_c': 10.8, 'maxtemp_f': 51.5, 'mintemp_c': 7.1, 'mintemp_f': 44.9, 'avgtemp_c': 9.3, 'avgtemp_f': 48.7, 'maxwind_mph': 14.5, 'maxwind_kph': 23.4, 'totalprecip_mm': 0.21, 'totalprecip_in': 0.01, 'totalsnow_cm': 0.0, 'avgvis_km': 10.0, 'avgvis_miles': 6.0, 'avghumidity': 77.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 87, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'uv': 2.0, 'air_quality': {'co': 238.06799999999998, 'no2': 14.255999999999998, 'o3': 57.96799999999999, 'so2': 3.1240000000000006, 'pm2_5': 1.4399999999999997, 'pm10': 2.7880000000000003, 'us-epa-index': 1, 'gb-defra-index': 1}}
# ...

# %%
url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=lhr&days=3&aqi=yes&alerts=yes"
response = requests.get(url)
data = response.json()

forecast = data['forecast']
for forecastday in forecast["forecastday"]:
    date = forecastday["date"]
    print(forecastday['day']['maxtemp_c'])
# Out:
# 10.8
# 11.4
# 8.5

# %%
url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=lhr&days=3&aqi=yes&alerts=yes"
response = requests.get(url)
data = response.json()

forecast = data['forecast']
for forecastday in forecast["forecastday"]:
    date = forecastday["date"]
    print(forecastday['date'])
# Out:
# 2023-11-15
# 2023-11-16
# 2023-11-17

# %%
url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=lhr&days=3&aqi=yes&alerts=yes"
response = requests.get(url)
data = response.json()

forecast = data['forecast']
for forecastday in forecast["forecastday"]:
    date = forecastday["date"]
    print(forecastday['date'],forecastday['day']['maxtemp_c'])
# Out:
# 2023-11-15 10.8
# 2023-11-16 11.4
# 2023-11-17 8.5

# %%
url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=lhr&days=3&aqi=yes&alerts=yes"
response = requests.get(url)
data = response.json()

forecast = data['forecast']
for forecastday in forecast["forecastday"]:
    if forecastday['day']['maxtemp_c'] > maxtemp_c:
      maxtemp_c = forecastday['day']['maxtemp_c']
      maxdate = forecastday["date"]
print(maxtemp_c, maxdate)
# Out:
# 11.4 2023-11-16
